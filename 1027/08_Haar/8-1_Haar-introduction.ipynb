# %% [markdown]
# # 哈爾特徵（Haar-like Feature）
#
# 哈爾特徵是一種常用於影像的特徵，其優點為計算量少，因此常用於簡單物件的辨識。<br>
# 以下將介紹哈爾特徵的計算方式。

# %% [markdown]
# ## 哈爾特徵計算
# 哈爾特徵由黑色區域及白色區域組成的矩形遮罩，其計算方式為：將哈爾特徵放於目標區域上，計算目標區域上黑色區域的總和減去白色區域的總和。舉下圖為例，其計算為2-1（黑色減去白色區域）。
# ![haar-like_feature_demo.png](attachment:haar-like_feature_demo.png)
# 不同種類的哈爾特徵便是藉由黑色及白色區域位置的不同，可適用於不同種類的特徵。
#
# ## OpenCV使用的哈爾特徵
# OpenCV中使用的哈爾特徵分類如下：
# - Edge features：用於檢測邊緣特徵，包含水平、垂直及旋轉類型。
# - Line features：用於檢測直線特徵，包含水平、垂直及旋轉類型。
# - Center-surround features：用於檢測中心特徵，包含平放及旋轉類型。
# ![haarfeatures.png](attachment:haarfeatures.png)
# （圖片來源：https://docs.opencv.org/4.1.1/d5/d54/group__objdetect.html ）
#
# ![obama.png](attachment:obama.png)
# ## OpenCV中的detectMultiScale()
# 由於影像中物件的大小並非固定，因此detectMultiScale()函數會將輸入圖片進行多次的縮放及辨識，因此此分類器可適用於不同大小的物件辨識。
#
#
#
# ## Haar feature 相關影片
# 影片連結：https://www.youtube.com/watch?v=hPCTwxF0qf4
